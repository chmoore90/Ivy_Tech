# %% [markdown]
# ## M07 Getting Started with Python

# %% [markdown]
# Item 1 - Input and Output

# %%
name    = input("Enter Employee Name")
salary  = input("Enter salary")
company = input ("Enter Company name")
print("Printing Employee Details")
print ("Name", "Salary", "Company")
print (name, salary, company)
# Out:
# Printing Employee Details
# Name Salary Company
# Chloe 1000000 My Company

# %% [markdown]
# Item 2 - Python Functions

# %%
# add_numbers is a function that takes two numbers and adds them together.
def add_numbers(x, y):
    return x + y

add_numbers(1, 2)
# Out:
# 3

# %%
# add_numbers updated to take an optional 3rd parameter. Using print allows printing of multiple expressions within a single cell.
def add_numbers(x,y,z=None): 
    if (z==None):
        return x+y
    else: 
        return x+y+z

print(add_numbers(1, 2)) 
print(add_numbers(1, 2, 3))
# Out:
# 3
# 6

# %%
# add_numbers updated to take an optional flag parameter.
def add_numbers(x, y, z=None, flag=False):
    if (flag):
        print('Flag is true!')
    if (z==None):
        return x + y
    else:
        return x + y + z
    
print(add_numbers(1, 2, flag=True))
# Out:
# Flag is true!
# 3

# %%
# Assign function add_numbers to variable a.
def add_numbers(x,y):
    return x+y

a = add_numbers
a(1,2)
# Out:
# 3

# %% [markdown]
# Item 3 - Types and Sequences

# %%
# This code returns portions of a string, similar to the substring function in SQL.
x = 'This is a string'
print(x[0]) #first character
print(x[0:1]) #first character, but we have explicitly set the end character
print(x[0:2]) #first two characters
# Out:
# T
# T
# Th

# %%
# This will return the last element of the string.
x = 'This is a string'
x[-4:-2]
# Out:
# 'ri'

# %%
# This is a slice from the beginning of the string and stopping before the 3rd element..
x = 'This is a string'
x[:3]
# Out:
# 'Thi'

# %%
# split returns a list of all the words in a string, or a list split on a specific character.
firstname = 'Jean-Luc Picard'.split(' ')[0] # [0] selects the first element of the list
lastname = 'Jean-Luc Picard'.split(' ')[-1] # [-1] selects the last element of the list
print(firstname)
print(lastname)
# Out:
# Jean-Luc
# Picard

# %% [markdown]
# Item 4 - Reading and Writing to CSV Files

# %%
# load data from a CSV file ant ourput the first 12 dictionaries.

import csv


with open('worldstats.csv') as csvfile:
    stats = list(csv.DictReader(csvfile))
    
stats[:12] # The first 12 dictionaries in our list.
# Out:
# [{'country': 'Arab World',
#   'year': '2015',
#   'Population': '392022276.0',
#   'GDP': '2530101503617.0'},
#  {'country': 'Arab World',
#   'year': '2014',
#   'Population': '384222592.0',
#   'GDP': '2873599811404.59'},
#  {'country': 'Arab World',
#   'year': '2013',
#   'Population': '376504253.0',
#   'GDP': '2846994251978.35'},
#  {'country': 'Arab World',
#   'year': '2012',
#   'Population': '368802611.0',
#   'GDP': '2773269952553.33'},
#  {'country': 'Arab World',
#   'year': '2011',
#   'Population': '361031820.0',
#   'GDP': '2497944765462.02'},
#  {'country': 'Arab World',
#   'year': '2010',
#   'Population': '353112237.0',
#   'GDP': '2103824906396.06'},
#  {'country': 'Arab World',
#   'year': '2009',
#   'Population': '345054176.0',
#   'GDP': '1798878411325.04'},
#  {'country': 'Arab World',
#   'year': '2008',
#   'Population': '336886468.0',
#   'GDP': '2081342637384.07'},
#  {'country': 'Arab World',
#   'year': '2007',
#   'Population': '328766559.0',
#   'GDP': '1641666468060.34'},
#  {'country': 'Arab World',
#   'year': '2006',
#   'Population': '320906736.0',
#   'GDP': '1404189584203.33'},
#  {'country': 'Arab World',
#   'year': '2005',
#   'Population': '313430911.0',
#   'GDP': '1184734704133.27'},
#  {'country': 'Arab World',
#   'year': '2004',
#   'Population': '306387415.0',
#   'GDP': '963918019742.793'}]

# %%
# this code will get the avg population for each country across all years recorded.
CountryName = set(d['country'] for d in stats) # get the country names
avg_gdp = []

for t in CountryName: # iterate over all the countries
    pop = 0
    i = 0
    for d in stats: # iterate over all dictionaries
        if d['country'] == t: # if the country name matches
            pop += float(d['Population']) # add the hwy mpg
            i += 1 # increment the count
    avg_gdp.append((t, pop / i)) # append the tuple ('CountryName', 'pop')

avg_gdp.sort(key=lambda x: x[0]) # sort by country name i.e. column 0.
avg_gdp
# Out:
# [('Afghanistan', 17486405.56756757),
#  ('Albania', 3057358.75),
#  ('Algeria', 24231377.964285713),
#  ('Andorra', 55704.36363636364),
#  ('Angola', 15970584.258064516),
#  ('Antigua and Barbuda', 74671.66666666667),
#  ('Arab World', 236525898.16666666),
#  ('Argentina', 31825662.943396226),
#  ('Armenia', 3116336.230769231),
#  ('Aruba', 93601.22222222222),
#  ('Australia', 16553687.732142856),
#  ('Austria', 7775068.178571428),
#  ('Azerbaijan', 8317427.692307692),
#  ('Bahamas, The', 247038.0357142857),
#  ('Bahrain', 738295.0555555555),
#  ('Bangladesh', 101968876.85714285),
#  ('Barbados', 267581.27777777775),
#  ('Belarus', 9835230.76923077),
#  ('Belgium', 10056939.75),
#  ('Belize', 195191.9107142857),
#  ('Benin', 5386003.375),
#  ('Bermuda', 57297.88888888889),
#  ('Bhutan', 578109.8888888889),
#  ('Bolivia', 6768447.821428572),
#  ('Bosnia and Herzegovina', 3827420.5),
#  ('Botswana', 1299510.1785714286),
#  ('Brazil', 142141187.19642857),
#  ('Brunei Darussalam', 260721.72549019608),
#  ('Bulgaria', 8193774.361111111),
#  ('Burkina Faso', 9343365.75),
#  ('Burundi', 5659120.625),
#  ('Cabo Verde', 407017.3333333333),
#  ('Cambodia', 10497298.184210526),
#  ('Cameroon', 12276285.160714285),
#  ('Canada', 26895112.55357143),
#  ('Caribbean small states', 5783630.321428572),
#  ('Cayman Islands', 41781.5),
#  ('Central African Republic', 2920544.4821428573),
#  ('Central Europe and the Baltics', 107155956.76923077),
#  ('Chad', 6605594.303571428),
#  ('Channel Islands', 151521.1),
#  ('Chile', 12762286.392857144),
#  ('China', 1066369196.4285715),
#  ('Colombia', 32578898.42857143),
#  ('Comoros', 516388.2571428571),
#  ('Congo, Dem. Rep.', 37369751.21428572),
#  ('Congo, Rep.', 2416454.8928571427),
#  ('Costa Rica', 3005777.9285714286),
#  ("Cote d'Ivoire", 11730286.42857143),
#  ('Croatia', 4421001.380952381),
#  ('Cuba', 10465748.681818182),
#  ('Cyprus', 875382.0975609756),
#  ('Czech Republic', 10340717.23076923),
#  ('Denmark', 5162780.375),
#  ('Djibouti', 707735.6551724138),
#  ('Dominica', 71869.79487179487),
#  ('Dominican Republic', 6865502.571428572),
#  ('Early-demographic dividend', 1960044504.635812),
#  ('East Asia & Pacific', 1717731046.7142856),
#  ('East Asia & Pacific (IDA & IBRD countries)', 1492029028.357143),
#  ('East Asia & Pacific (excluding high income)', 1511214301.2857144),
#  ('Ecuador', 9880230.44642857),
#  ('Egypt, Arab Rep.', 57186975.196078435),
#  ('El Salvador', 5056545.0),
#  ('Equatorial Guinea', 433371.9423076923),
#  ('Eritrea', 3815048.9),
#  ('Estonia', 1359822.8095238095),
#  ('Ethiopia', 64248565.82857143),
#  ('Euro area', 307849332.33928573),
#  ('Europe & Central Asia', 811815527.9285715),
#  ('Europe & Central Asia (IDA & IBRD countries)', 437302791.8518519),
#  ('Europe & Central Asia (excluding high income)', 394577378.037037),
#  ('European Union', 469780390.75),
#  ('Faroe Islands', 47767.1875),
#  ('Fiji', 685667.3571428572),
#  ('Finland', 4947596.732142857),
#  ('Fragile and conflict affected situations', 408396914.25),
#  ('France', 57478618.96428572),
#  ('French Polynesia', 163844.41666666666),
#  ('Gabon', 968129.3571428572),
#  ('Gambia, The', 977947.1224489796),
#  ('Georgia', 4309126.923076923),
#  ('Germany', 80213397.36956522),
#  ('Ghana', 14808121.107142856),
#  ('Greece', 9932809.57142857),
#  ('Greenland', 53831.84444444445),
#  ('Grenada', 99609.64102564103),
#  ('Guatemala', 9191155.30357143),
#  ('Guinea', 8816275.6),
#  ('Guinea-Bissau', 1167837.347826087),
#  ('Guyana', 725639.9464285715),
#  ('Haiti', 8980160.72),
#  ('Heavily indebted poor countries (HIPC)', 370484466.83928573),
#  ('High income', 982694434.5357143),
#  ('Honduras', 4747623.625),
#  ('Hong Kong SAR, China', 5458207.232142857),
#  ('Hungary', 10137746.48),
#  ('IBRD only', 3222123511.278669),
#  ('IDA & IBRD total', 4142870584.2250977),
#  ('IDA blend', 342299101.23214287),
#  ('IDA only', 578447971.7142857),
#  ('IDA total', 920747072.9464285),
#  ('Iceland', 250842.0892857143),
#  ('India', 845251573.6428572),
#  ('Indonesia', 182629925.48979592),
#  ('Iran, Islamic Rep.', 49096419.18867925),
#  ('Iraq', 17848359.075),
#  ('Ireland', 3583295.1964285714),
#  ('Isle of Man', 79592.78947368421),
#  ('Israel', 4861562.857142857),
#  ('Italy', 56127223.26785714),
#  ('Jamaica', 2276862.4464285714),
#  ('Japan', 117528200.55357143),
#  ('Jordan', 3744561.5098039214),
#  ('Kazakhstan', 15852204.26923077),
#  ('Kenya', 23200918.05357143),
#  ('Kiribati', 76712.21739130435),
#  ('Korea, Rep.', 40483463.78571428),
#  ('Kosovo', 1748687.8125),
#  ('Kuwait', 1810923.5),
#  ('Kyrgyz Republic', 5050461.538461538),
#  ('Lao PDR', 5227259.78125),
#  ('Late-demographic dividend', 1739342715.2142856),
#  ('Latin America & Caribbean', 425639663.0714286),
#  ('Latin America & Caribbean (excluding high income)', 372716910.3035714),
#  ('Latin America & the Caribbean (IDA & IBRD countries)', 411401410.89285713),
#  ('Latvia', 2233072.5714285714),
#  ('Least developed countries: UN classification', 676747604.1290323),
#  ('Lebanon', 3702571.3214285714),
#  ('Lesotho', 1490386.2),
#  ('Liberia', 2324455.7678571427),
#  ('Libya', 5522209.230769231),
#  ('Liechtenstein', 29482.86046511628),
#  ('Lithuania', 3294449.1904761903),
#  ('Low & middle income', 4084313252.885812),
#  ('Low income', 452384939.1785714),
#  ('Lower middle income', 1845908403.9107144),
#  ('Luxembourg', 400394.23214285716),
#  ('Macao SAR, China', 424657.0882352941),
#  ('Macedonia, FYR', 2021631.6153846155),
#  ('Madagascar', 12155601.839285715),
#  ('Malawi', 8713224.75),
#  ('Malaysia', 18008101.589285713),
#  ('Maldives', 275348.3333333333),
#  ('Mali', 9800846.020408163),
#  ('Malta', 358154.63636363635),
#  ('Marshall Islands', 48117.14705882353),
#  ('Mauritania', 2063442.0727272728),
#  ('Mauritius', 1119106.625),
#  ('Mexico', 81636985.5),
#  ('Micronesia, Fed. Sts.', 102349.46666666666),
#  ('Middle East & North Africa', 264250951.0),
#  ('Middle East & North Africa (IDA & IBRD countries)', 294160756.45454544),
#  ('Middle East & North Africa (excluding high income)', 297396185.22727275),
#  ('Middle income', 3749306002.7072406),
#  ('Moldova', 3621130.923076923),
#  ('Monaco', 29803.738095238095),
#  ('Mongolia', 2355732.2),
#  ('Montenegro', 615857.75),
#  ('Morocco', 23425335.92857143),
#  ('Mozambique', 18036073.666666668),
#  ('Myanmar', 53215495.75),
#  ('Namibia', 1723202.111111111),
#  ('Nepal', 18494221.589285713),
#  ('Netherlands', 14642166.517857144),
#  ('New Caledonia', 150879.36111111112),
#  ('New Zealand', 3443247.272727273),
#  ('Nicaragua', 3913048.1071428573),
#  ('Niger', 8782314.0),
#  ('Nigeria', 97178615.26785715),
#  ('North America', 275628673.66071427),
#  ('Norway', 4259531.017857143),
#  ('OECD members', 1044581890.3392857),
#  ('Oman', 1857351.7647058824),
#  ('Other small states', 19491418.975609757),
#  ('Pacific island small states', 1825264.6341463414),
#  ('Pakistan', 105088684.89285715),
#  ('Palau', 18980.153846153848),
#  ('Panama', 2408992.8928571427),
#  ('Papua New Guinea', 4150891.1272727274),
#  ('Paraguay', 4281828.117647059),
#  ('Peru', 20594892.55357143),
#  ('Philippines', 60227052.66071428),
#  ('Poland', 38267946.73076923),
#  ('Portugal', 9773178.5),
#  ('Post-demographic dividend', 945000525.5892857),
#  ('Pre-demographic dividend', 432795508.85714287),
#  ('Puerto Rico', 3295342.777777778),
#  ('Qatar', 686813.0652173914),
#  ('Romania', 21734715.379310343),
#  ('Russian Federation', 145609195.25925925),
#  ('Rwanda', 6405919.964285715),
#  ('Samoa', 173571.58823529413),
#  ('San Marino', 28668.5),
#  ('Sao Tome and Principe', 162321.42857142858),
#  ('Saudi Arabia', 17147372.666666668),
#  ('Senegal', 7671508.875),
#  ('Serbia', 7401445.714285715),
#  ('Seychelles', 68820.67857142857),
#  ('Sierra Leone', 3748160.8928571427),
#  ('Singapore', 3191124.125),
#  ('Slovak Republic', 5373618.384615385),
#  ('Slovenia', 2015625.0),
#  ('Small states', 26441339.217391305),
#  ('Solomon Islands', 341228.3541666667),
#  ('Somalia', 10524276.666666666),
#  ('South Africa', 34384882.957240485),
#  ('South Asia', 1103955096.6607144),
#  ('South Asia (IDA & IBRD)', 1103955096.6607144),
#  ('South Sudan', 10760475.0),
#  ('Spain', 38603773.21428572),
#  ('Sri Lanka', 16024714.285714285),
#  ('St. Kitts and Nevis', 46268.82142857143),
#  ('St. Lucia', 150884.72972972973),
#  ('St. Vincent and the Grenadines', 101188.91071428571),
#  ('Sub-Saharan Africa', 520750138.2608119),
#  ('Sub-Saharan Africa (IDA & IBRD countries)', 520750138.2608119),
#  ('Sub-Saharan Africa (excluding high income)', 520681317.5822405),
#  ('Sudan', 20698902.10714286),
#  ('Suriname', 414836.35714285716),
#  ('Swaziland', 788319.7321428572),
#  ('Sweden', 8536001.964285715),
#  ('Switzerland', 6844429.195652174),
#  ('Syrian Arab Republic', 10751973.0625),
#  ('Tajikistan', 6654200.692307692),
#  ('Tanzania', 36668492.53571428),
#  ('Thailand', 51698523.64285714),
#  ('Timor-Leste', 1033770.5625),
#  ('Togo', 3784439.375),
#  ('Tonga', 97030.4),
#  ('Trinidad and Tobago', 1145206.9642857143),
#  ('Tunisia', 7946749.764705882),
#  ('Turkey', 51567124.14285714),
#  ('Turkmenistan', 4483912.137931035),
#  ('Tuvalu', 9509.52),
#  ('Uganda', 18328722.94642857),
#  ('Ukraine', 48792144.20689655),
#  ('United Arab Emirates', 3438954.1707317075),
#  ('United Kingdom', 57756796.428571425),
#  ('United States', 248675981.4642857),
#  ('Upper middle income', 1903397598.7965264),
#  ('Uruguay', 3054361.160714286),
#  ('Uzbekistan', 25621480.769230768),
#  ('Vanuatu', 176703.80555555556),
#  ('Venezuela, RB', 18617847.333333332),
#  ('Vietnam', 76682158.06451613),
#  ('Virgin Islands (U.S.)', 80992.88235294117),
#  ('West Bank and Gaza', 3333586.3636363638),
#  ('World', 5098646063.225098),
#  ('Yemen, Rep.', 18708423.0),
#  ('Zambia', 8126050.928571428),
#  ('Zimbabwe', 9383385.910714285)]

# %%
# What code would I use to get the average global population by year? Use the above code as an example, change what you need to make it work.

years = set(d["year"] for d in stats)
avg_gdp = []

for year in years:
    pop = 0
    i = 0
    for d in stats:
        if d["year"] == year:
            pop += float(d["Population"])
            i += 1
    avg_gdp.append((year, pop / i))

avg_gdp.sort(key=lambda x: x[0])
avg_gdp
# Out:
# [('1960', 210381812.85185185),
#  ('1961', 213095294.42222223),
#  ('1962', 213815632.97080293),
#  ('1963', 218450828.50364962),
#  ('1964', 223127304.30656934),
#  ('1965', 214105105.71917808),
#  ('1966', 217379282.56462586),
#  ('1967', 218387189.22),
#  ('1968', 219007347.92857143),
#  ('1969', 223887286.93506494),
#  ('1970', 218136417.10493827),
#  ('1971', 220276962.17682928),
#  ('1972', 225018021.40243903),
#  ('1973', 229722349.90243903),
#  ('1974', 234432721.2195122),
#  ('1975', 233396056.94642857),
#  ('1976', 236408383.3195266),
#  ('1977', 236574446.51744187),
#  ('1978', 242347468.18128654),
#  ('1979', 243983814.28901735),
#  ('1980', 233774344.21195653),
#  ('1981', 234467425.87700534),
#  ('1982', 237555827.1276596),
#  ('1983', 240727000.74074075),
#  ('1984', 243887210.14210525),
#  ('1985', 245918772.45876288),
#  ('1986', 249281141.93333334),
#  ('1987', 249295582.14070353),
#  ('1988', 251848285.74257424),
#  ('1989', 257417132.29268292),
#  ('1990', 242063942.71300447),
#  ('1991', 245953819.4349776),
#  ('1992', 249997855.95515695),
#  ('1993', 251987318.16740087),
#  ('1994', 253759013.76419213),
#  ('1995', 249122826.98312235),
#  ('1996', 251842047.70168066),
#  ('1997', 256698914.80590716),
#  ('1998', 258281383.17154813),
#  ('1999', 260883493.27083334),
#  ('2000', 261583343.0),
#  ('2001', 265265820.3237705),
#  ('2002', 268832749.52355504),
#  ('2003', 272417193.5185128),
#  ('2004', 275006071.58640957),
#  ('2005', 278624539.91815764),
#  ('2006', 281114933.9737309),
#  ('2007', 285912055.59232247),
#  ('2008', 290761367.55407375),
#  ('2009', 295729233.2747228),
#  ('2010', 299526111.7711782),
#  ('2011', 303367689.0324951),
#  ('2012', 309951457.1719966),
#  ('2013', 314022189.23470354),
#  ('2014', 330025755.27044946),
#  ('2015', 356623119.1075198)]

# %% [markdown]
# Item 5 - Using Pandas to Analyze Data

# %%
# use Pandas to import a CSV file and print the first 5 rows
import pandas as pd

df = pd.read_csv('worldstats.csv')
df.head(5)
# Out:
#       country  year   Population           GDP
# 0  Arab World  2015  392022276.0  2.530102e+12
# 1  Arab World  2014  384222592.0  2.873600e+12
# 2  Arab World  2013  376504253.0  2.846994e+12
# 3  Arab World  2012  368802611.0  2.773270e+12
# 4  Arab World  2011  361031820.0  2.497945e+12

# %%
# use Pandas to import a CSV file and print the last 5 rows
import pandas as pd

df = pd.read_csv('worldstats.csv')
df.tail(5)
# Out:
#         country  year  Population           GDP
# 11206  Zimbabwe  1964   4279561.0  1.217138e+09
# 11207  Zimbabwe  1963   4140804.0  1.159512e+09
# 11208  Zimbabwe  1962   4006262.0  1.117602e+09
# 11209  Zimbabwe  1961   3876638.0  1.096647e+09
# 11210  Zimbabwe  1960   3752390.0  1.052990e+09

# %% [markdown]
# Item 6 - Make It Your Own

# %%
# Average GPD per country, sorted by highest to lowest GDP

countries = set(d["country"] for d in stats)
avg_gdp = []

for country in countries:
    gdp = 0
    i = 0
    for d in stats:
        if d["country"] == country:
            gdp += float(d["GDP"])
            i += 1
    avg_gdp.append((country, gdp / i))

avg_gdp.sort(key=lambda x: x[1], reverse=True)
avg_gdp
# Out:
# [('World', 25057431804975.082),
#  ('High income', 18888714196031.637),
#  ('OECD members', 18625118185189.535),
#  ('Post-demographic dividend', 17933388225706.734),
#  ('Europe & Central Asia', 8369088820058.251),
#  ('North America', 7159335076673.701),
#  ('European Union', 7050979670678.526),
#  ('United States', 6557344633928.571),
#  ('IDA & IBRD total', 6404546226998.531),
#  ('Low & middle income', 6001581717711.536),
#  ('IBRD only', 5900415283501.995),
#  ('Middle income', 5896540304868.892),
#  ('East Asia & Pacific', 5887535634759.6),
#  ('Euro area', 5282968657973.061),
#  ('Upper middle income', 4509156967255.758),
#  ('Late-demographic dividend', 3915023901274.0737),
#  ('Early-demographic dividend', 2745145840605.9727),
#  ('Japan', 2549480643266.6143),
#  ('East Asia & Pacific (excluding high income)', 2135230760259.5774),
#  ('East Asia & Pacific (IDA & IBRD countries)', 2131164598551.517),
#  ('Europe & Central Asia (IDA & IBRD countries)', 2053238606833.6472),
#  ('Germany', 1868061799948.433),
#  ('Europe & Central Asia (excluding high income)', 1740155448128.061),
#  ('Latin America & Caribbean', 1720651501877.239),
#  ('Latin America & the Caribbean (IDA & IBRD countries)', 1643861497909.1003),
#  ('China', 1605357569831.83),
#  ('Latin America & Caribbean (excluding high income)', 1403181305265.8967),
#  ('Lower middle income', 1385396461681.2805),
#  ('France', 1130842707641.354),
#  ('United Kingdom', 1081010203462.6338),
#  ('Middle East & North Africa', 1001811243844.1637),
#  ('Italy', 909748495174.7775),
#  ('Russian Federation', 876857260346.8916),
#  ('Middle East & North Africa (excluding high income)', 810037352975.4894),
#  ('Middle East & North Africa (IDA & IBRD countries)', 804136803329.7192),
#  ('Central Europe and the Baltics', 785566571821.1621),
#  ('Arab World', 777272269181.4697),
#  ('South Asia (IDA & IBRD)', 619642387746.4391),
#  ('South Asia', 619642387746.4391),
#  ('Brazil', 612265238774.3513),
#  ('Canada', 599854160515.1945),
#  ('Spain', 514969459705.60657),
#  ('IDA total', 508116507899.8875),
#  ('India', 487372933888.3267),
#  ('Fragile and conflict affected situations', 484922896979.1361),
#  ('Sub-Saharan Africa', 420281744500.541),
#  ('Sub-Saharan Africa (IDA & IBRD countries)', 420281744500.541),
#  ('Sub-Saharan Africa (excluding high income)', 419867946415.57),
#  ('Mexico', 404519010805.40955),
#  ('Korea, Rep.', 387104534544.24225),
#  ('Australia', 386537264507.8333),
#  ('Least developed countries: UN classification', 355397955282.26514),
#  ('Netherlands', 331770420412.25287),
#  ('Poland', 283340321246.96313),
#  ('Switzerland', 270712500963.69708),
#  ('Pre-demographic dividend', 267645504892.38605),
#  ('IDA blend', 256943481261.51968),
#  ('IDA only', 251490811657.83478),
#  ('Indonesia', 228003969258.01083),
#  ('Turkey', 217333733628.08514),
#  ('Saudi Arabia', 214170444679.83615),
#  ('Sweden', 213742072518.3479),
#  ('Belgium', 199533932988.0909),
#  ('Argentina', 178577908382.12152),
#  ('Low income', 174802356216.51562),
#  ('Heavily indebted poor countries (HIPC)', 162530022605.41537),
#  ('Austria', 159880655394.88156),
#  ('Norway', 148900460553.98465),
#  ('Small states', 146746845251.72894),
#  ('Iran, Islamic Rep.', 144651421480.81647),
#  ('Denmark', 132145649092.60962),
#  ('Other small states', 128093653400.28226),
#  ('South Africa', 127284585008.23282),
#  ('United Arab Emirates', 125867820188.78177),
#  ('Czech Republic', 119120240082.18227),
#  ('Thailand', 111460762598.39331),
#  ('Greece', 108831564368.07774),
#  ('Finland', 103752154590.93318),
#  ('Hong Kong SAR, China', 95751488659.11093),
#  ('Venezuela, RB', 90889884372.88197),
#  ('Romania', 89044200949.39651),
#  ('Hungary', 87772215770.6374),
#  ('Portugal', 87730283340.40639),
#  ('Ukraine', 87192159877.6836),
#  ('Nigeria', 87053239740.06395),
#  ('Colombia', 86858546615.75476),
#  ('Israel', 80701854763.31088),
#  ('Kazakhstan', 79794565335.0139),
#  ('Malaysia', 79452906846.97069),
#  ('Ireland', 78606252544.70052),
#  ('Egypt, Arab Rep.', 75284555303.65038),
#  ('Singapore', 71584613292.92825),
#  ('Philippines', 69011807480.53017),
#  ('Chile', 66686051640.89109),
#  ('Myanmar', 65634607858.42662),
#  ('Pakistan', 63293287386.72892),
#  ('Iraq', 62220751735.87064),
#  ('Vietnam', 59879312335.70446),
#  ('Algeria', 59743051257.15892),
#  ('New Zealand', 55898440388.375984),
#  ('Slovak Republic', 53537815185.412056),
#  ('Peru', 47998249243.55011),
#  ('Kuwait', 45480826160.27936),
#  ('Croatia', 42765896178.467514),
#  ('Bangladesh', 42552224817.94146),
#  ('Libya', 42338821232.761955),
#  ('Qatar', 38037822863.8338),
#  ('Angola', 36638050726.13615),
#  ('Puerto Rico', 36137189024.48839),
#  ('Slovenia', 35838511681.44867),
#  ('Morocco', 34225596258.13236),
#  ('Belarus', 32272276541.294617),
#  ('Cuba', 30588634455.637634),
#  ('Serbia', 29593014607.691116),
#  ('Lithuania', 27094739467.83221),
#  ('Bulgaria', 26617537593.60931),
#  ('Ecuador', 25235631197.24515),
#  ('Uzbekistan', 24384592806.86224),
#  ('Azerbaijan', 24312854049.693703),
#  ('Caribbean small states', 23715573665.561466),
#  ('Lebanon', 21321863547.501854),
#  ('Oman', 19450508015.836967),
#  ('Latvia', 18306420392.11737),
#  ('Sudan', 18076714460.219162),
#  ('Luxembourg', 18014009897.18624),
#  ('Tunisia', 17623185677.15693),
#  ('Tanzania', 17180782700.84643),
#  ('Dominican Republic', 17121388367.351763),
#  ('Ethiopia', 17031946968.083761),
#  ('Sri Lanka', 16246826380.160769),
#  ('Guatemala', 15395928890.090618),
#  ('Yemen, Rep.', 15191767665.626703),
#  ('Uruguay', 14690372407.372843),
#  ('Estonia', 14473879702.818203),
#  ('South Sudan', 13407414252.66338),
#  ('Macao SAR, China', 13354914360.274523),
#  ('Kenya', 13314043397.367117),
#  ('Bahrain', 12005347176.54793),
#  ('Costa Rica', 11981785929.619112),
#  ('Turkmenistan', 11631144742.843798),
#  ('Syrian Arab Republic', 11614592446.587706),
#  ('Bosnia and Herzegovina', 10769162090.983091),
#  ('Cyprus', 10666995194.257914),
#  ("Cote d'Ivoire", 10601613892.158705),
#  ('Panama', 10494062180.357143),
#  ('Cameroon', 10029696031.229544),
#  ('Ghana', 9631487586.37002),
#  ('Jordan', 9115082796.340462),
#  ('El Salvador', 9079016737.254902),
#  ('Trinidad and Tobago', 8113253324.575684),
#  ('Paraguay', 7879204849.391323),
#  ('Channel Islands', 7744863659.814341),
#  ('Bolivia', 7598343206.004995),
#  ('Georgia', 7459385396.215547),
#  ('Congo, Dem. Rep.', 6558753485.543695),
#  ('Iceland', 6443278371.783164),
#  ('West Bank and Gaza', 6341615715.337737),
#  ('Mozambique', 6323459417.59619),
#  ('Uganda', 6244689483.206717),
#  ('Macedonia, FYR', 6232039872.595716),
#  ('Zambia', 6060690096.209859),
#  ('Zimbabwe', 5917198214.349694),
#  ('Afghanistan', 5868060666.0915),
#  ('Albania', 5833936150.3292055),
#  ('Somalia', 5670666666.666667),
#  ('Jamaica', 5654619111.252817),
#  ('Namibia', 5420991952.907386),
#  ('Brunei Darussalam', 5405907241.292737),
#  ('Honduras', 5384526594.526382),
#  ('Gabon', 5277190606.772265),
#  ('Senegal', 5153135617.467534),
#  ('Armenia', 5134564112.753594),
#  ('Nepal', 5120021458.475403),
#  ('Cambodia', 4930086395.125267),
#  ('Kosovo', 4871138312.138837),
#  ('Haiti', 4818263942.222255),
#  ('Mauritius', 4708830198.913837),
#  ('Botswana', 4260341288.029048),
#  ('Mali', 3918758370.1052756),
#  ('Pacific island small states', 3830314380.551597),
#  ('Papua New Guinea', 3805468480.3524218),
#  ('Mongolia', 3797458137.681299),
#  ('Madagascar', 3781862614.8231177),
#  ('Guinea', 3761683493.270331),
#  ('Nicaragua', 3675904495.2383866),
#  ('Moldova', 3661245761.035424),
#  ('Lao PDR', 3553373319.286776),
#  ('Bahamas, The', 3471158572.6212516),
#  ('Congo, Rep.', 3406085559.9213204),
#  ('Isle of Man', 3353614408.5599732),
#  ('Malta', 3351015783.637262),
#  ('Tajikistan', 3340804930.1947665),
#  ('Kyrgyz Republic', 3305862116.5173163),
#  ('Burkina Faso', 3180721627.565219),
#  ('Montenegro', 3143918841.0815682),
#  ('Equatorial Guinea', 3071355762.2090855),
#  ('Chad', 2961053573.8756137),
#  ('Barbados', 2833659244.6297235),
#  ('Benin', 2513078405.1277356),
#  ('Monaco', 2465977340.1799197),
#  ('Niger', 2381991579.4581704),
#  ('Cayman Islands', 2109738293.5085),
#  ('Malawi', 2075939076.5525222),
#  ('Aruba', 2036355058.9695833),
#  ('Rwanda', 2025582286.1746292),
#  ('Bermuda', 1999886340.4641383),
#  ('Liechtenstein', 1919981692.379386),
#  ('Faroe Islands', 1829838050.5083706),
#  ('French Polynesia', 1818946387.6992695),
#  ('Fiji', 1547043265.6548276),
#  ('New Caledonia', 1497461055.7844913),
#  ('Mauritania', 1394755979.8944817),
#  ('Togo', 1364902027.075653),
#  ('Andorra', 1358661347.3280332),
#  ('Swaziland', 1297696817.1966813),
#  ('Suriname', 1262980427.787412),
#  ('San Marino', 1219464739.4502785),
#  ('Sierra Leone', 1211746201.1654541),
#  ('Greenland', 1045808153.2956265),
#  ('Eritrea', 1031287009.3362305),
#  ('Maldives', 959977731.9116151),
#  ('Burundi', 959723430.6174475),
#  ('Central African Republic', 905562948.8847579),
#  ('Guyana', 802122149.0483457),
#  ('Timor-Leste', 792346921.99333),
#  ('Cabo Verde', 762208670.7655272),
#  ('Djibouti', 708863249.517361),
#  ('St. Lucia', 678298778.4487711),
#  ('Bhutan', 672286604.0038263),
#  ('Lesotho', 668542536.6982038),
#  ('Liberia', 641499119.6428572),
#  ('Virgin Islands (U.S.)', 641000004.7058823),
#  ('Antigua and Barbuda', 633621069.0208609),
#  ('Belize', 538463924.9893891),
#  ('Gambia, The', 457310327.8605898),
#  ('Seychelles', 415757510.7643798),
#  ('Grenada', 408688486.3936559),
#  ('Solomon Islands', 375969594.7185479),
#  ('Guinea-Bissau', 367042391.0345073),
#  ('Samoa', 348523935.96339744),
#  ('Vanuatu', 319436683.8833343),
#  ('Comoros', 293201939.50285107),
#  ('St. Kitts and Nevis', 265521613.57555375),
#  ('St. Vincent and the Grenadines', 264543186.3914785),
#  ('Dominica', 262424188.5938771),
#  ('Micronesia, Fed. Sts.', 221228591.8608417),
#  ('Tonga', 181659294.77428895),
#  ('Sao Tome and Principe', 177634654.41508737),
#  ('Palau', 157364846.15384614),
#  ('Marshall Islands', 109294713.5137952),
#  ('Kiribati', 69406987.7991815),
#  ('Tuvalu', 20378753.71072986)]

# %%
# Population of Canada

import pandas as pd

with open("worldstats-canadapop.csv", "w") as can:
    can.write("year, population\n")
    for d in stats:
        if d["country"] == "Canada":
            can.write(f"{d['year']}, {d['Population']}\n")

df = pd.read_csv("worldstats-canadapop.csv")
df
# Out:
#     year   population
# 0   2015   35851774.0
# 1   2014   35543658.0
# 2   2013   35155499.0
# 3   2012   34751476.0
# 4   2011   34342780.0
# 5   2010   34005274.0
# 6   2009   33628571.0
# 7   2008   33245773.0
# 8   2007   32887928.0
# 9   2006   32570505.0
# 10  2005   32312000.0
# 11  2004   31995000.0
# 12  2003   31676000.0
# 13  2002   31362000.0
# 14  2001   31081900.0
# 15  2000   30769700.0
# 16  1999   30499200.0
# 17  1998   30247900.0
# 18  1997   29987200.0
# 19  1996   29671900.0
# 20  1995   29354000.0
# 21  1994   29111906.0
# 22  1993   28833410.0
# 23  1992   28519597.0
# 24  1991   28171682.0
# 25  1990   27791000.0
# 26  1989   27379000.0
# 27  1988   26895000.0
# 28  1987   26550000.0
# 29  1986   26204000.0
# 30  1985   25942000.0
# 31  1984   25702000.0
# 32  1983   25456000.0
# 33  1982   25202000.0
# 34  1981   24900000.0
# 35  1980   24593000.0
# 36  1979   24277000.0
# 37  1978   24036000.0
# 38  1977   23796000.0
# 39  1976   23518000.0
# 40  1975   23209000.0
# 41  1974   22774087.0
# 42  1973   22369408.0
# 43  1972   21993631.0
# 44  1971   21645535.0
# 45  1970   21324000.0
# 46  1969   21028000.0
# 47  1968   20744000.0
# 48  1967   20412000.0
# 49  1966   20048000.0
# 50  1965   19678000.0
# 51  1964   19325000.0
# 52  1963   18964000.0
# 53  1962   18614000.0
# 54  1961   18271000.0
# 55  1960   17909009.0

# %%
"""
Python can be used to quickly sort data and perform calculations. Since it is interacting directly with the data file (eg. csv), it will much faster than Excel or Tableau.
In addition to pandas, there are other libraries like numpy and matplotlib that can assist in parsing, performing calculations, and display data.
"""
# Out:
# '\nPython can be used to quickly sort data and perform calculations. Since it is interacting directly with the data file (eg. csv), it will much faster than Excel or Tableau.\nIn addition to pandas, there are other libraries like numpy and matplotlib that can assist in parsing, performing calculations, and display data.\n'
